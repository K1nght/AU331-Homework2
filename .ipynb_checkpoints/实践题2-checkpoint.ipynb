# %% [markdown]
# # 实践题二
# # 1）仅使用numpy实现三层神经网络BP训练算法(输入d维向量，中间h个隐含神经元，输出c>1类单热向量编码，隐含层使用sigmoid激活函数，输入输出层使用线性激活函数)，损失函数用均方误差或者交叉熵损失函数。

# %%
# import library
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from tqdm import tqdm

# %% [markdown]
# # 我设计的神经网络采用了静态图架构，即需要在训练前将网络连接关系建立好。
# # 并且我设计了三个父类分别为层类Hlayer、损失函数类Hloss、优化器类Hoptimizer，不同的连接层与需要使用的损失函数和优化器就对这些父类进行继承。

# %%
# 层父类
class Hlayer(object):
    
    def __init__(self, trainable=True):
        self.trainable = trainable        # 表示这层是否有可训练参数
        self.input = None                # 记录层输入
        self.output = None               # 记录层输出
        self.upstream_gradient =  None   # 上游梯度
        self.downstream_gradient = None  # 下游梯度
        
    def __call__(self, input):           # 可直接调用层计算得到输出
        pass
    
    def backward(self):                  # 反向传播计算梯度 
        pass
     
    def summary(self):                   # 打印该层信息
        pass

# %%
# 损失函数父类
class Hloss(object):
    
    def __init__(self):
        self.input = None               # 记录损失函数的输入
        self.label = None               # 记录数据真实标签
        self.output = None              # 记录损失函数输出
        self.gradient = None            # 下游梯度
        
    def __call__(self, input, label):   # 可直接调用损失函数进行计算
        pass
    
    def backward(self):                 # 反向传播计算梯度
        pass
    
    def summary(self):                  # 打印损失函数信息
        pass

# %%
# 优化器父类
class Hoptimizer(object):
    
    def __init__(self, learning_rate=0.001):
        self.learning_rate = learning_rate # 默认优化器只有学习率一个参数
        
    def __call__(self, gradient):          # 直接调用优化器计算优化梯度
        pass

# %% [markdown]
# ## 输入层
# * 不可训练
# * input=output

# %%
class Hinput(Hlayer):
    
    def __init__(self):
        super(Hinput, self).__init__()
        self.trainable = False
        
    def __call__(self, input):
        # print("input", input.shape)
        self.input = input
        self.output = input
        return self.output
    
    def backward(self):
        try:
            assert self.upstream_gradient is not None
        except AssertionError:
            print("ERROR! There is no upstream gradient!")
        else:
            self.downstream_gradient = self.upstream_gradient
            return self.downstream_gradient
        
    def summary(self, i):
        print("{:>15} {:>15} {:>15} {:>15}".format("Input-%d"%i, "[-1, -1]", str(self.trainable), 0))

# %% [markdown]
# ## Sigmoid函数层
# * 不可训练
# ![img](./img/Sigmoid.png)

# %%
def sigmoid(x):
    return 1/(1+np.exp(-x))

class Hsigmoid(Hlayer):
    
    def __init__(self):
        super(Hsigmoid, self).__init__()
        self.trainable = False
    
    def __call__(self, input):
        # print(input.shape)
        self.input = input
        self.output = sigmoid(input)
        return self.output

    def backward(self):
        try:
            assert self.upstream_gradient is not None
        except AssertionError:
            print("ERROR! There is no upstream gradient!")
        else:
            self.downstream_gradient = self.upstream_gradient*sigmoid(self.input)*(1-sigmoid(self.input))
            return self.downstream_gradient
        
    def summary(self, i):
        print("{:>15} {:>15} {:>15} {:>15}".format("Sigmoid-%d"%i, "[-1, -1]", str(self.trainable), 0))

# %% [markdown]
# ## 线性全连接层
# * 可训练
# * y=wx+b

# %%
class Hlinear(Hlayer):
    
    def __init__(self, input_size, output_size):
        """
            input_size:输入维度
            output_size:输出维度
        """
        super(Hlinear, self).__init__()
        self.input_size = input_size
        self.output_size = output_size
        self.trainable = True
        self.local_gradient = None
        self.w = np.random.randn(input_size+1, output_size)
        
    def __call__(self, input):
        # print(input.shape)
        input = np.concatenate((input, np.ones((input.shape[0], 1))), axis=1)
        self.input = input
        self.output = np.matmul(input, self.w)
        return self.output

    def backward(self):
        try:
            assert self.upstream_gradient is not None
        except AssertionError:
            print("ERROR! There is no upstream gradient!")
        else:
            self.local_gradient = np.matmul(np.transpose(self.input), self.upstream_gradient)
            self.downstream_gradient = np.matmul(self.upstream_gradient, np.transpose(self.w))
            self.downstream_gradient = self.downstream_gradient[:,:-1]  # 不需要将bias相关输出作为下游梯度
            return self.downstream_gradient
    
    def update(self, optimizer):
        self.w -= optimizer(self.local_gradient)
        
    def summary(self, i):
        print("{:>15} {:>15} {:>15} {:>15}".format("Linear-%d"%i, "[-1,%d]"%self.output_size, str(self.trainable), np.size(self.w)))
    
    def init_w(self):
        pass

# %% [markdown]
# ## 交叉熵损失函数

# %%
def softmax(x):
    exp_x = np.exp(x)
    return exp_x / np.sum(exp_x, axis=1).reshape(len(exp_x),1)

def convert_to_one_hot(label,class_num):
    label = np.eye(class_num)[label]
    return label

class HCrossEntropy(Hloss):
    
    def __init__(self):
        super(HCrossEntropy, self).__init__()
    
    def __call__(self, input, label):
        """
            input:
            label:默认为input第二维度上的数量为分类的数量，采用one-hot编码对label进行编码
        """
        # print(input.shape)
        class_num = input.shape[1]  # 默认input第二维度上的数量为分类的数量
        label = convert_to_one_hot(label, class_num)  # 采用one-hot编码对label进行编码
        self.input = input
        self.label = label
        input = softmax(input)
        self.output = (-1)*np.sum(np.log(input)*label)
        return self.output
        
    def summary(self):
        print("Loss function: Cross Entropy")
    
    def backward(self):
        self.gradient = softmax(self.input) - self.label
        return self.gradient

# %% [markdown]
# ## sgd随机梯度下降优化器
# * 输入学习率

# %%
class Hsgd(Hoptimizer):
    
    def __init__(self, learning_rate):
        super(Hsgd, self).__init__(learning_rate)
        
    def __call__(self, gradient):
        return gradient*self.learning_rate

# %% [markdown]
# ## 神经网络类定义
# ### 使用列表sequential存储堆叠的层
# ### criterion存储神经网络最后使用的损失函数
# * add_layer函数用于添加实例化层
# * add_criterion函数用于添加损失函数
# * 可直接调用网络实例化对象计算输出结果
# * loss函数得到网络损失函数输出
# * predict函数得到网络分类编号输出
# * backward函数反向传播计算网络可训练层梯度
# * step函数对网络可训练层使用指定优化器进行参数更新
# * summary函数可以打印网络实例化对象基本信息

# %%
class Hfnn:
    
    def __init__(self):
        self.sequential = []
        self.len_sequential = 0
        self.criterion = None
        
    def add_layer(self, layer):  # 添加实例化层
        l = layer
        self.sequential.append(l)
        self.len_sequential += 1
        
    def add_criterion(self, criterion):  # 添加损失函数
        self.criterion = criterion
        
    def __call__(self, input):  # 可直接调用网络实例化对象计算输出结果
        x = input.copy()
        for layer in self.sequential:
            x = layer(x)
        return x
    
    def loss(self, output, label):  # 返回网络损失函数输出
        loss = self.criterion(output, label)
        return loss
    
    def predict(self, input):  # 得到网络分类编号输出
        output = self(input)
        pred = np.argmax(output, axis=1)
        return pred
    
    def backward(self):  # 反向传播计算网络可训练层梯度
        downstream_gradient = self.criterion.backward()
        for i in range(self.len_sequential-1, -1, -1):
            self.sequential[i].upstream_gradient = downstream_gradient
            downstream_gradient = self.sequential[i].backward()
            
    def step(self, optimizer):  # 根据梯度和指定的优化器更新可训练层网络参数
        for layer in self.sequential:
            if layer.trainable:
                layer.update(optimizer)
                
    def summary(self):  # 打印网络基本信息
        print('-'*64)
        print("{:>15} {:>15} {:>15} {:>15}".format("Layer (type)", "Output Shape", "Trainable", "Param #"))
        print('='*64)
        for i, layer in enumerate(self.sequential):
            layer.summary(i)
        print('='*64)
        self.criterion.summary()

# %% [markdown]
# # 2) 在iris数据集上对1中实现的算法测试，并于实践题1的结果进行比较

# %%
# 将特征变量和标签分开并打乱数据集
def shuffle_data(data, label):
    index = np.arange(len(label))
    np.random.shuffle(index)
    data = data[index, :]
    label = label[index]
    return data, label

# %%
# 划分80%训练数据和20%测试数据
def train_test_divide(data, label, proportion):
    """
        proportion: range from 0 to 1, means the proportion of training data in the total data
    """
    train_length = int(len(label)*proportion)
    train_data = data[:train_length, :]
    train_label = label[:train_length]
    test_data = data[train_length:, :]
    test_label = label[train_length:]
    print("Shape: train_data", train_data.shape,
          "|train_label", train_label.shape,
          "|test_data", test_data.shape,
          "|test_label", test_label.shape)
    
    return train_data, train_label, test_data, test_label

# %%
# 读取Iris数据集
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
iris_df = pd.read_csv('iris.data', names=names)
iris_df.head()
iris_data = iris_df.values[:,:-1].astype(np.float)
# 三类鸢尾花分别编号为 0，1，2
iris_label = pd.Categorical(iris_df['class']).codes.astype(np.float)

# %%
class training_process:
    def __init__(self, train_data, train_label, test_data, test_label, model, optimizer,
                  epoch=10):
        """
            train_data: 训练数据
            train_label: 训练数据标签
            test_data: 测试数据
            test_label: 测试数据标签
            model: 使用的模型
            criterion: 损失函数
            optimizer: 优化方法
            epoch: 训练轮数
        """
        self.train_data = train_data
        self.train_label = train_label
        self.test_data = test_data
        self.test_label = test_label
        self.model = model
        self.optimizer = optimizer
        self.train_size = len(train_label)
        self.test_size = len(test_label)
        self.epoch = epoch
        
        # 用来保存每次训练过程中训练集误差、测试集误差、训练集精度以及测试集精度
        self.loss_train = []
        self.loss_test = []
        self.acc_train = []
        self.acc_test = []
    
    # 清空已有的训练过程
    def clear(self):
        self.loss_train = []
        self.loss_test = []
        self.acc_train = []
        self.acc_test = []
        
    # 输出训练过程数据
    def checkpoint(self):
        return self.loss_train, self.loss_test, self.acc_train, self.acc_test
    
    # 定义训练过程
    def train(self):
        for epoch in tqdm(range(self.epoch)):
            # 正向传播计算误差
            train_outputs = self.model(self.train_data)
            train_loss = self.model.loss(train_outputs, self.train_label)
            # 反向传播计算梯度
            self.model.backward()
            # 优化器更新模型参数
            self.model.step(self.optimizer)

            self.loss_train.append(train_loss)
            # 测试模型在训练集和测试集上的精度以及计算在测试集上的loss
            train_correct = 0
            test_correct = 0
            test_outputs = self.model(self.test_data)
            test_loss = self.model.loss(test_outputs, self.test_label)

            train_predicted = self.model.predict(self.train_data)
            train_correct += (train_predicted == self.train_label).sum().item()

            test_predicted = self.model.predict(self.test_data)
            test_correct += (test_predicted == self.test_label).sum().item()
                
                    
            self.acc_train.append(train_correct/self.train_size*100)
            self.acc_test.append(test_correct/self.test_size*100)
            self.loss_test.append(test_loss)
            # 打印训练过程信息
            print('[epoch: %d]|training loss: %.6f| testing loss: %.6f' %
             (epoch + 1, train_loss, test_loss))
            print('Accuracy of the network on the train data: %.3f %%' % (train_correct/self.train_size*100)) 
            print('Accuracy of the network on the test data: %.3f %%' % (test_correct/self.test_size*100))

        print('Finished Training')
      
    # 作出四张图，分别是训练集误差曲线、测试集误差曲线、训练集精度曲线、测试集精度曲线
    def plot_loss_and_acc(self, figname):
        fig = plt.figure(figsize=(12, 32))
        # 训练集误差曲线
        ax1 = fig.add_subplot(411)
        ax1.plot(np.arange(self.epoch)+1, np.array(self.loss_train))
        ax1.set_xlabel('Steps')
        ax1.set_ylabel('Loss on train data')
        ax1.set_title('Loss of the network on the training data')
        ax1.grid(True)
        
        # 测试集误差曲线
        ax2 = fig.add_subplot(412)
        ax2.plot(np.arange(self.epoch)+1, np.array(self.loss_test))
        ax2.set_xlabel('Steps')
        ax2.set_ylabel('Loss on test data')
        ax2.set_title('Loss of the network on the testing data')
        ax2.grid(True)

        # 训练集精度曲线
        ax3 = fig.add_subplot(413)
        ax3.plot(np.arange(self.epoch)+1, np.array(self.acc_train))
        ax3.set_xlabel('Epoch')
        ax3.set_ylabel('Accuracy on train data')
        ax3.set_title('Accuracy of the network on the training data')
        ax3.grid(True)

        # 测试集精度曲线
        ax4 = fig.add_subplot(414)
        ax4.plot(np.arange(self.epoch)+1, np.array(self.acc_test))
        ax4.set_xlabel('Epoch')
        ax4.set_ylabel('Accuracy on test data')
        ax4.set_title('Accurracy of the network on the testing data')
        ax4.grid(True)

        plt.savefig('./img/%s_loss_acc.png' % figname)
        plt.show()

# %%
# 打乱数据集并进行80%训练和20%测试划分
iris_data, iris_label = shuffle_data(iris_data, iris_label)
train_data, train_label, test_data, test_label = train_test_divide(iris_data, iris_label, 0.8)
# 计算训练集数据均值和方差
train_mean = np.mean(train_data, axis=0)
train_std = np.std(train_data, axis=0)
# 预处理数据
train_data = (train_data - train_mean)/train_std
test_data = (test_data - train_mean)/train_std

train_label = train_label.astype(np.int)
test_label = test_label.astype(np.int)
# Out:
# Shape: train_data (120, 4) |train_label (120,) |test_data (30, 4) |test_label (30,)

# %% [markdown]
# # 构建三层神经网络实例化对象
# ## 输入层维度为4，隐藏层维度为12，输出层维度为3
# ![img](./img/my_fnn架构.JPG)

# %%
input_size = iris_data.shape[1]
output_size = 3

fnn = Hfnn()
fnn.add_layer(Hinput())
fnn.add_layer(Hlinear(4, 12))
fnn.add_layer(Hsigmoid())
fnn.add_layer(Hlinear(12, output_size))
fnn.add_criterion(HCrossEntropy())

fnn.summary()
# Out:
# ----------------------------------------------------------------
#    Layer (type)    Output Shape       Trainable         Param #
# ================================================================
#         Input-0        [-1, -1]           False               0
#        Linear-1         [-1,12]            True              60
#       Sigmoid-2        [-1, -1]           False               0
#        Linear-3          [-1,3]            True              39
# ================================================================
# Loss function: Cross Entropy

# %%
optimizer = Hsgd(learning_rate=0.014)
training1 = training_process(train_data, train_label, test_data, test_label, fnn, optimizer,
                  epoch=100)
training1.train()
training1.plot_loss_and_acc('My_fnn')
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 100/100 [00:00<00:00, 694.60it/s]
# [epoch: 1]|training loss: 333.215343| testing loss: 25.056499
# Accuracy of the network on the train data: 67.500 %
# Accuracy of the network on the test data: 60.000 %
# [epoch: 2]|training loss: 91.074079| testing loss: 19.752466
# Accuracy of the network on the train data: 70.833 %
# Accuracy of the network on the test data: 60.000 %
# [epoch: 3]|training loss: 74.546125| testing loss: 16.940728
# Accuracy of the network on the train data: 74.167 %
# Accuracy of the network on the test data: 63.333 %
# [epoch: 4]|training loss: 63.691984| testing loss: 14.582238
# Accuracy of the network on the train data: 85.000 %
# Accuracy of the network on the test data: 80.000 %
# [epoch: 5]|training loss: 56.024759| testing loss: 13.271455
# Accuracy of the network on the train data: 88.333 %
# Accuracy of the network on the test data: 86.667 %
# [epoch: 6]|training loss: 50.429842| testing loss: 11.806582
# Accuracy of the network on the train data: 93.333 %
# Accuracy of the network on the test data: 93.333 %
# [epoch: 7]|training loss: 46.239412| testing loss: 11.214262
# Accuracy of the network on the train data: 90.833 %
# Accuracy of the network on the test data: 90.000 %
# [epoch: 8]|training loss: 42.999610| testing loss: 10.117481
# Accuracy of the network on the train data: 95.000 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 9]|training loss: 40.418333| testing loss: 9.895014
# Accuracy of the network on the train data: 90.833 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 10]|training loss: 38.301011| testing loss: 8.986549
# Accuracy of the network on the train data: 95.833 %
# Accuracy of the network on the test data: 93.333 %
# [epoch: 11]|training loss: 36.508205| testing loss: 8.939884
# Accuracy of the network on the train data: 91.667 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 12]|training loss: 34.961166| testing loss: 8.170244
# Accuracy of the network on the train data: 95.833 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 13]|training loss: 33.576506| testing loss: 8.175757
# Accuracy of the network on the train data: 93.333 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 14]|training loss: 32.336558| testing loss: 7.539953
# Accuracy of the network on the train data: 95.833 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 15]|training loss: 31.184102| testing loss: 7.528950
# Accuracy of the network on the train data: 95.000 %
# Accuracy of the network on the test data: 93.333 %
# [epoch: 16]|training loss: 30.130944| testing loss: 7.026341
# Accuracy of the network on the train data: 95.833 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 17]|training loss: 29.140121| testing loss: 6.974495
# Accuracy of the network on the train data: 95.833 %
# Accuracy of the network on the test data: 93.333 %
# [epoch: 18]|training loss: 28.226187| testing loss: 6.592217
# Accuracy of the network on the train data: 95.833 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 19]|training loss: 27.368219| testing loss: 6.501904
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 93.333 %
# [epoch: 20]|training loss: 26.571383| testing loss: 6.215306
# Accuracy of the network on the train data: 95.833 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 21]|training loss: 25.824450| testing loss: 6.099313
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 22]|training loss: 25.125217| testing loss: 5.880541
# Accuracy of the network on the train data: 95.833 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 23]|training loss: 24.467243| testing loss: 5.752526
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 24]|training loss: 23.846419| testing loss: 5.578129
# Accuracy of the network on the train data: 95.833 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 25]|training loss: 23.258784| testing loss: 5.448621
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 26]|training loss: 22.701045| testing loss: 5.302440
# Accuracy of the network on the train data: 95.833 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 27]|training loss: 22.170673| testing loss: 5.177902
# Accuracy of the network on the train data: 95.833 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 28]|training loss: 21.665452| testing loss: 5.050272
# Accuracy of the network on the train data: 95.833 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 29]|training loss: 21.183639| testing loss: 4.933744
# Accuracy of the network on the train data: 95.833 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 30]|training loss: 20.723674| testing loss: 4.819372
# Accuracy of the network on the train data: 95.833 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 31]|training loss: 20.284223| testing loss: 4.711699
# Accuracy of the network on the train data: 95.833 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 32]|training loss: 19.864067| testing loss: 4.607744
# Accuracy of the network on the train data: 95.833 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 33]|training loss: 19.462105| testing loss: 4.508675
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 34]|training loss: 19.077318| testing loss: 4.413508
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 35]|training loss: 18.708767| testing loss: 4.322391
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 36]|training loss: 18.355574| testing loss: 4.234937
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 37]|training loss: 18.016924| testing loss: 4.151039
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 38]|training loss: 17.692051| testing loss: 4.070482
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 39]|training loss: 17.380241| testing loss: 3.993116
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 40]|training loss: 17.080823| testing loss: 3.918778
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 41]|training loss: 16.793166| testing loss: 3.847323
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 42]|training loss: 16.516680| testing loss: 3.778614
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 96.667 %
# [epoch: 43]|training loss: 16.250805| testing loss: 3.712521
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 44]|training loss: 15.995018| testing loss: 3.648920
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 45]|training loss: 15.748825| testing loss: 3.587696
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 46]|training loss: 15.511760| testing loss: 3.528739
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 47]|training loss: 15.283382| testing loss: 3.471945
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 48]|training loss: 15.063278| testing loss: 3.417215
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 49]|training loss: 14.851054| testing loss: 3.364456
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 50]|training loss: 14.646341| testing loss: 3.313579
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 51]|training loss: 14.448790| testing loss: 3.264501
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 52]|training loss: 14.258068| testing loss: 3.217140
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 53]|training loss: 14.073864| testing loss: 3.171422
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 54]|training loss: 13.895880| testing loss: 3.127273
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 55]|training loss: 13.723837| testing loss: 3.084626
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 56]|training loss: 13.557468| testing loss: 3.043416
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 57]|training loss: 13.396523| testing loss: 3.003581
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 58]|training loss: 13.240762| testing loss: 2.965061
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 59]|training loss: 13.089960| testing loss: 2.927801
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 60]|training loss: 12.943901| testing loss: 2.891748
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 61]|training loss: 12.802383| testing loss: 2.856850
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 62]|training loss: 12.665212| testing loss: 2.823061
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 63]|training loss: 12.532205| testing loss: 2.790333
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 64]|training loss: 12.403188| testing loss: 2.758624
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 65]|training loss: 12.277996| testing loss: 2.727892
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 66]|training loss: 12.156470| testing loss: 2.698097
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 67]|training loss: 12.038463| testing loss: 2.669202
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 68]|training loss: 11.923831| testing loss: 2.641171
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 69]|training loss: 11.812439| testing loss: 2.613969
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 70]|training loss: 11.704160| testing loss: 2.587564
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 71]|training loss: 11.598870| testing loss: 2.561925
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 72]|training loss: 11.496452| testing loss: 2.537022
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 73]|training loss: 11.396797| testing loss: 2.512827
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 74]|training loss: 11.299797| testing loss: 2.489314
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 75]|training loss: 11.205352| testing loss: 2.466455
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 76]|training loss: 11.113367| testing loss: 2.444228
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 77]|training loss: 11.023748| testing loss: 2.422608
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 78]|training loss: 10.936410| testing loss: 2.401572
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 79]|training loss: 10.851267| testing loss: 2.381100
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 80]|training loss: 10.768242| testing loss: 2.361172
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 81]|training loss: 10.687256| testing loss: 2.341766
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 82]|training loss: 10.608239| testing loss: 2.322866
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 83]|training loss: 10.531120| testing loss: 2.304452
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 84]|training loss: 10.455832| testing loss: 2.286508
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 85]|training loss: 10.382313| testing loss: 2.269018
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 86]|training loss: 10.310502| testing loss: 2.251965
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 87]|training loss: 10.240340| testing loss: 2.235335
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 88]|training loss: 10.171772| testing loss: 2.219114
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 89]|training loss: 10.104745| testing loss: 2.203287
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 90]|training loss: 10.039207| testing loss: 2.187841
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 91]|training loss: 9.975111| testing loss: 2.172765
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 92]|training loss: 9.912408| testing loss: 2.158044
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 93]|training loss: 9.851054| testing loss: 2.143669
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 94]|training loss: 9.791007| testing loss: 2.129628
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 95]|training loss: 9.732224| testing loss: 2.115909
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 96]|training loss: 9.674666| testing loss: 2.102504
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 97]|training loss: 9.618296| testing loss: 2.089401
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 98]|training loss: 9.563076| testing loss: 2.076592
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 99]|training loss: 9.508972| testing loss: 2.064067
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# [epoch: 100]|training loss: 9.455950| testing loss: 2.051817
# Accuracy of the network on the train data: 96.667 %
# Accuracy of the network on the test data: 100.000 %
# Finished Training
